# %%
import zipfile
import os
import shutil
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
from PIL import Image, ImageEnhance
import random
import shutil
import cv2
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import label_binarize

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
zip_path = "/content/drive/MyDrive/FODS PROJECT FOLDER/German Dataset.zip"
extract_path = "GTS"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Files extracted to:", extract_path)
# Out:
# Files extracted to: GTS

# %%
german_base = "GTS"

german_train_csv = os.path.join(german_base, "Train.csv")
german_train_img_base = os.path.join(german_base, "Train")

german_test_csv = os.path.join(german_base, "Test.csv")
german_test_img_base = os.path.join(german_base, "Test")



ge_train_df = pd.read_csv(german_train_csv)
ge_test_df = pd.read_csv(german_test_csv)


print("German Train CSV shape:", ge_train_df.shape)
print("German Test CSV shape:", ge_test_df.shape)
# Out:
# German Train CSV shape: (39209, 8)
# German Test CSV shape: (12630, 8)

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from sklearn.metrics import classification_report, confusion_matrix

# ============================================================
# 1️⃣ PATHS
# ============================================================
train_dir = "/content/GTS/Train"
test_dir  = "/content/GTS/Test"
test_csv  = "/content/GTS/Test.csv"

# ============================================================
# 2️⃣ DATA PIPELINE (Optimized)
# ============================================================

IMG_SIZE = (96, 96)
BATCH_SIZE = 32

# GPU-based data augmentation
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
])

# Train/validation datasets using image_dataset_from_directory
train_ds_raw = tf.keras.utils.image_dataset_from_directory(
    directory=train_dir,
    validation_split=0.15,
    subset='training',
    seed=42,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)

val_ds_raw = tf.keras.utils.image_dataset_from_directory(
    directory=train_dir,
    validation_split=0.15,
    subset='validation',
    seed=42,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)

num_classes = len(train_ds_raw.class_names)
print("Detected classes:", num_classes)

# Normalize pixel values (0–1)
normalization_layer = layers.Rescaling(1./255)

# Prefetch and cache for GPU efficiency
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds_raw.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds_raw.cache().prefetch(buffer_size=AUTOTUNE)

# ============================================================
# 3️⃣ BUILD MODEL (MobileNetV2)
# ============================================================

base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(*IMG_SIZE, 3))
base_model.trainable = False  # Freeze base layers

model = models.Sequential([
    data_augmentation,
    normalization_layer,
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dropout(0.3),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(num_classes, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.summary()

# ============================================================
# 4️⃣ TRAIN
# ============================================================

lr_cb = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=2)
ckpt_cb = ModelCheckpoint('best_mobilenet_model.keras', save_best_only=True, monitor='val_accuracy', mode='max')
es_cb   = EarlyStopping(monitor='val_accuracy', patience=4, restore_best_weights=True)

history = model.fit(
    train_ds,
    epochs=25,
    validation_data=val_ds,
    callbacks=[lr_cb, ckpt_cb, es_cb],
    verbose=1
)

# ============================================================
# 5️⃣ OPTIONAL FINE-TUNING
# ============================================================

base_model.trainable = True
for layer in base_model.layers[:-30]:
    layer.trainable = False

model.compile(optimizer=tf.keras.optimizers.Adam(1e-5),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

fine_history = model.fit(
    train_ds,
    epochs=25,
    validation_data=val_ds,
    callbacks=[lr_cb, ckpt_cb, es_cb],
    verbose=1
)
# Out:
# Found 39209 files belonging to 43 classes.
# Using 33328 files for training.
# Found 39209 files belonging to 43 classes.
# Using 5881 files for validation.
# Detected classes: 43
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_96             │ (None, 3, 3, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ ?                      │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,257,984 (8.61 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 2,257,984 (8.61 MB)
# Epoch 1/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 55s 25ms/step - accuracy: 0.3464 - loss: 2.3214 - val_accuracy: 0.6475 - val_loss: 1.0974 - learning_rate: 0.0010
# Epoch 2/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - accuracy: 0.5423 - loss: 1.3994 - val_accuracy: 0.6931 - val_loss: 0.9421 - learning_rate: 0.0010
# Epoch 3/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 20s 19ms/step - accuracy: 0.5833 - loss: 1.2493 - val_accuracy: 0.7286 - val_loss: 0.8247 - learning_rate: 0.0010
# Epoch 4/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - accuracy: 0.6140 - loss: 1.1605 - val_accuracy: 0.7594 - val_loss: 0.7586 - learning_rate: 0.0010
# Epoch 5/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 20s 19ms/step - accuracy: 0.6320 - loss: 1.0993 - val_accuracy: 0.7606 - val_loss: 0.7088 - learning_rate: 0.0010
# Epoch 6/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 20s 19ms/step - accuracy: 0.6345 - loss: 1.0783 - val_accuracy: 0.7796 - val_loss: 0.6721 - learning_rate: 0.0010
# Epoch 7/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 20s 19ms/step - accuracy: 0.6521 - loss: 1.0309 - val_accuracy: 0.7793 - val_loss: 0.6742 - learning_rate: 0.0010
# Epoch 8/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - accuracy: 0.6531 - loss: 1.0181 - val_accuracy: 0.7885 - val_loss: 0.6508 - learning_rate: 0.0010
# Epoch 9/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 21s 20ms/step - accuracy: 0.6555 - loss: 1.0121 - val_accuracy: 0.8026 - val_loss: 0.6216 - learning_rate: 0.0010
# Epoch 10/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - accuracy: 0.6698 - loss: 0.9690 - val_accuracy: 0.8073 - val_loss: 0.6090 - learning_rate: 0.0010
# Epoch 11/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 20s 19ms/step - accuracy: 0.6693 - loss: 0.9846 - val_accuracy: 0.7956 - val_loss: 0.6130 - learning_rate: 0.0010
# Epoch 12/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 19s 18ms/step - accuracy: 0.6700 - loss: 0.9652 - val_accuracy: 0.8017 - val_loss: 0.6014 - learning_rate: 0.0010
# Epoch 13/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 20s 19ms/step - accuracy: 0.6905 - loss: 0.9185 - val_accuracy: 0.8347 - val_loss: 0.5327 - learning_rate: 5.0000e-04
# Epoch 14/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 19s 18ms/step - accuracy: 0.7017 - loss: 0.8877 - val_accuracy: 0.8325 - val_loss: 0.5272 - learning_rate: 5.0000e-04
# Epoch 15/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 22s 19ms/step - accuracy: 0.7047 - loss: 0.8739 - val_accuracy: 0.8386 - val_loss: 0.5212 - learning_rate: 5.0000e-04
# Epoch 16/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 19s 18ms/step - accuracy: 0.7078 - loss: 0.8673 - val_accuracy: 0.8378 - val_loss: 0.5139 - learning_rate: 5.0000e-04
# Epoch 17/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 20s 19ms/step - accuracy: 0.7140 - loss: 0.8437 - val_accuracy: 0.8427 - val_loss: 0.4985 - learning_rate: 5.0000e-04
# Epoch 18/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - accuracy: 0.7090 - loss: 0.8406 - val_accuracy: 0.8414 - val_loss: 0.5016 - learning_rate: 5.0000e-04
# Epoch 19/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 20s 19ms/step - accuracy: 0.7107 - loss: 0.8578 - val_accuracy: 0.8414 - val_loss: 0.4991 - learning_rate: 5.0000e-04
# Epoch 20/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 20s 19ms/step - accuracy: 0.7185 - loss: 0.8224 - val_accuracy: 0.8531 - val_loss: 0.4769 - learning_rate: 2.5000e-04
# Epoch 21/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 20s 19ms/step - accuracy: 0.7221 - loss: 0.8129 - val_accuracy: 0.8519 - val_loss: 0.4655 - learning_rate: 2.5000e-04
# Epoch 22/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - accuracy: 0.7209 - loss: 0.8143 - val_accuracy: 0.8563 - val_loss: 0.4598 - learning_rate: 2.5000e-04
# Epoch 23/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 21s 20ms/step - accuracy: 0.7244 - loss: 0.8050 - val_accuracy: 0.8577 - val_loss: 0.4537 - learning_rate: 2.5000e-04
# Epoch 24/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 19s 18ms/step - accuracy: 0.7265 - loss: 0.7922 - val_accuracy: 0.8567 - val_loss: 0.4552 - learning_rate: 2.5000e-04
# Epoch 25/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 21s 20ms/step - accuracy: 0.7320 - loss: 0.7805 - val_accuracy: 0.8594 - val_loss: 0.4596 - learning_rate: 2.5000e-04
# Epoch 1/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 44s 32ms/step - accuracy: 0.3913 - loss: 4.1271 - val_accuracy: 0.7373 - val_loss: 0.7974 - learning_rate: 1.0000e-05
# Epoch 2/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 33s 32ms/step - accuracy: 0.5065 - loss: 1.9855 - val_accuracy: 0.7354 - val_loss: 0.8090 - learning_rate: 1.0000e-05
# Epoch 3/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 32s 31ms/step - accuracy: 0.5529 - loss: 1.5331 - val_accuracy: 0.7490 - val_loss: 0.7425 - learning_rate: 1.0000e-05
# Epoch 4/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 42s 32ms/step - accuracy: 0.5989 - loss: 1.3003 - val_accuracy: 0.7681 - val_loss: 0.6786 - learning_rate: 1.0000e-05
# Epoch 5/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 33s 31ms/step - accuracy: 0.6288 - loss: 1.1523 - val_accuracy: 0.7970 - val_loss: 0.6041 - learning_rate: 1.0000e-05
# Epoch 6/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 33s 32ms/step - accuracy: 0.6664 - loss: 1.0334 - val_accuracy: 0.8124 - val_loss: 0.5511 - learning_rate: 1.0000e-05
# Epoch 7/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 33s 31ms/step - accuracy: 0.6853 - loss: 0.9628 - val_accuracy: 0.8330 - val_loss: 0.4963 - learning_rate: 1.0000e-05
# Epoch 8/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 33s 32ms/step - accuracy: 0.7061 - loss: 0.8905 - val_accuracy: 0.8436 - val_loss: 0.4697 - learning_rate: 1.0000e-05
# Epoch 9/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 33s 31ms/step - accuracy: 0.7237 - loss: 0.8167 - val_accuracy: 0.8551 - val_loss: 0.4281 - learning_rate: 1.0000e-05
# Epoch 10/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 34s 32ms/step - accuracy: 0.7432 - loss: 0.7673 - val_accuracy: 0.8652 - val_loss: 0.3977 - learning_rate: 1.0000e-05
# Epoch 11/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 33s 32ms/step - accuracy: 0.7556 - loss: 0.7307 - val_accuracy: 0.8783 - val_loss: 0.3679 - learning_rate: 1.0000e-05
# Epoch 12/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 33s 32ms/step - accuracy: 0.7667 - loss: 0.6941 - val_accuracy: 0.8845 - val_loss: 0.3490 - learning_rate: 1.0000e-05
# Epoch 13/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 33s 32ms/step - accuracy: 0.7765 - loss: 0.6587 - val_accuracy: 0.8915 - val_loss: 0.3248 - learning_rate: 1.0000e-05
# Epoch 14/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 34s 32ms/step - accuracy: 0.7908 - loss: 0.6244 - val_accuracy: 0.8995 - val_loss: 0.3032 - learning_rate: 1.0000e-05
# Epoch 15/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 33s 32ms/step - accuracy: 0.7984 - loss: 0.5934 - val_accuracy: 0.8997 - val_loss: 0.2954 - learning_rate: 1.0000e-05
# Epoch 16/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 34s 33ms/step - accuracy: 0.8065 - loss: 0.5571 - val_accuracy: 0.9097 - val_loss: 0.2748 - learning_rate: 1.0000e-05
# Epoch 17/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 33s 32ms/step - accuracy: 0.8154 - loss: 0.5453 - val_accuracy: 0.9119 - val_loss: 0.2631 - learning_rate: 1.0000e-05
# Epoch 18/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 34s 33ms/step - accuracy: 0.8259 - loss: 0.5243 - val_accuracy: 0.9138 - val_loss: 0.2564 - learning_rate: 1.0000e-05
# Epoch 19/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 34s 33ms/step - accuracy: 0.8314 - loss: 0.4908 - val_accuracy: 0.9196 - val_loss: 0.2395 - learning_rate: 1.0000e-05
# Epoch 20/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 33s 32ms/step - accuracy: 0.8394 - loss: 0.4721 - val_accuracy: 0.9282 - val_loss: 0.2247 - learning_rate: 1.0000e-05
# Epoch 21/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 33s 32ms/step - accuracy: 0.8451 - loss: 0.4496 - val_accuracy: 0.9269 - val_loss: 0.2220 - learning_rate: 1.0000e-05
# Epoch 22/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 33s 31ms/step - accuracy: 0.8511 - loss: 0.4363 - val_accuracy: 0.9281 - val_loss: 0.2151 - learning_rate: 1.0000e-05
# Epoch 23/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 34s 32ms/step - accuracy: 0.8548 - loss: 0.4185 - val_accuracy: 0.9320 - val_loss: 0.2051 - learning_rate: 5.0000e-06
# Epoch 24/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 33s 31ms/step - accuracy: 0.8594 - loss: 0.4067 - val_accuracy: 0.9311 - val_loss: 0.2035 - learning_rate: 5.0000e-06
# Epoch 25/25
# 1042/1042 ━━━━━━━━━━━━━━━━━━━━ 34s 33ms/step - accuracy: 0.8664 - loss: 0.3962 - val_accuracy: 0.9347 - val_loss: 0.1997 - learning_rate: 5.0000e-06
